# %%
import pandas as pd
import numpy as np

# %%
# Cargamos el csv a la variable data
data = pd.read_csv('https://gist.githubusercontent.com/eduardogpg/9a0e348884bf8b5e60db013a0429a59d/raw/3587f65f7914f6c7d02fb84489d34d2b16eb511a/users.csv', 
usecols=['name', 'age', 'gender', 'country', 'email'])

# Limpiamos de los valores NaN
data = data.dropna()

# Imprimimos los datos
data
# Out:
#                    name  age  gender         country  \
# 0      Mr Jerome Thomas   73    male   United States
# 1         Mr Gary Berry   70    male  United Kingdom
# 2       Mr Noham Dubois   40    male          France
# 3     Mrs Naja Johansen   63  female         Denmark
# 4    Mr Damien Marchand   61    male          France
# ..                  ...  ...     ...             ...
# 195       Mr Raul Bravo   46    male           Spain
# 196   Miss Maeva Fortin   40  female          Canada
# 197   Mr Gabriel Berger   40    male          France
# 198  Mrs Ülkü Tanrıkulu   37  female          Turkey
# 199     Mr Raff Valkema   60    male     Netherlands
#
#                            email
# 0      jerome.thomas@example.com
# 1         gary.berry@example.com
# 2       noham.dubois@example.com
# 3      naja.johansen@example.com
# 4    damien.marchand@example.com
# ..                           ...
# 195       raul.bravo@example.com
# 196     maeva.fortin@example.com
# ...

# %% [markdown]
# ### Obtener el nombre de todos los usuarios con una edad mayor a 40

# %%
data[data['age'] > 40] ['name']
# Out:
# 0         Mr Jerome Thomas
# 1            Mr Gary Berry
# 3        Mrs Naja Johansen
# 4       Mr Damien Marchand
# 5         Mr Harri Althoff
#               ...
# 191          Mr Noah Moore
# 193    Ms Delphine Ginnish
# 194    Madame Rosa Lefevre
# 195          Mr Raul Bravo
# 199        Mr Raff Valkema
# Name: name, Length: 122, dtype: object

# %% [markdown]
# ### Obtener el nombre de todos los usuarios con una edad mayor a 40 y de sexo femenino

# %%
data[(data['age'] > 40) & (data['gender'] == 'female')]
# Out:
#                         name  age  gender         country  \
# 3          Mrs Naja Johansen   63  female         Denmark
# 9       Miss Emilia Laitinen   53  female         Finland
# 10       Ms Cathriona Hanson   53  female         Ireland
# 11          Miss Maia Clarke   52  female     New Zealand
# 12         Ms Cathy Simmmons   55  female       Australia
# ..                       ...  ...     ...             ...
# 181           Mrs Avery King   57  female  United Kingdom
# 182          Mrs Soila Silva   63  female          Brazil
# 190  Miss Margrietha Holster   61  female     Netherlands
# 193      Ms Delphine Ginnish   58  female          Canada
# 194      Madame Rosa Lefevre   67  female     Switzerland
#
#                               email
# 3         naja.johansen@example.com
# 9       emilia.laitinen@example.com
# 10     cathriona.hanson@example.com
# 11          maia.clarke@example.com
# 12       cathy.simmmons@example.com
# ..                              ...
# ...

# %% [markdown]
# ### Obtener todos los usuarios cuyo email no termine con @example.com

# %%
# Converitimos a string los valores de la cadena de emails para que muestre todos aquellos que terminan con @example
# negamos toda la consulta con ~, mostrando solo aquel que no termina con @example.com
data[ ~ data['email'].str.endswith('@example.com')]
# Out:
#               name  age gender country                 email
# 151  Mr Thomas Lam   42   male  Canada  thomas.lam@gmail.com

# %% [markdown]
# ### Obtener el nombre y correo electronico de todos aquellos usuarios del pais Germany, Findland y Canada

# %%
data[ (data['country'] == 'Germany') | (data['country'] == 'Canada') | (data['country'] == 'Finland')]

# La alternativa a la sentencia anterior seria
# data[ data['country'].isin( ['Germany', 'Finland', 'Canada'])]
# Out:
#                        name  age  gender  country  \
# 5          Mr Harri Althoff   56    male  Germany
# 7         Ms Britta Weinert   35  female  Germany
# 9      Miss Emilia Laitinen   53  female  Finland
# 20     Mr Vincenzo Rauscher   25    male  Germany
# 21            Mr Louis Ross   60    male   Canada
# 31          Mr Toivo Kotila   27    male  Finland
# 36          Mr Anthony Wong   42    male   Canada
# 38        Mrs Lotta Rintala   26  female  Finland
# 41         Miss Iida Ketola   46  female  Finland
# 45        Ms Ilona Moilanen   22  female  Finland
# 47         Miss Ellen Rinne   66  female  Finland
# 50           Mr Theo Miller   33    male   Canada
# 53          Ms Aino Lassila   54  female  Finland
# 56       Ms Marcella Brosch   38  female  Germany
# 58       Miss Madison Ennis   49  female   Canada
# 72           Ms Megan Brown   26  female   Canada
# 79   Ms Hanne Aschenbrenner   64  female  Germany
# 85       Mrs Luisa Weißmann   32  female  Germany
# ...

# %% [markdown]
# ### Obtener el nombre y correo electronico de todos los usuarios de sexo femenino del pais Germany

# %%
data[ (data['gender'] == 'female') & (data['country'] == 'Germany')]
# Out:
#                        name  age  gender  country  \
# 7         Ms Britta Weinert   35  female  Germany
# 56       Ms Marcella Brosch   38  female  Germany
# 79   Ms Hanne Aschenbrenner   64  female  Germany
# 85       Mrs Luisa Weißmann   32  female  Germany
# 88            Mrs Hilda Epp   22  female  Germany
# 144        Ms Mareile Plate   51  female  Germany
#
#                                email
# 7         britta.weinert@example.com
# 56       marcella.brosch@example.com
# 79   hanne.aschenbrenner@example.com
# 85       luisa.weissmann@example.com
# 88             hilda.epp@example.com
# 144        mareile.plate@example.com

# %% [markdown]
# ### Obtener la cantidad de usuarios de sexo masculino en canada

# %%
# Contar solo los resultados que aparecen en genero (Aunque daria el mismo resultado si contamos nombres, emails u otro)
data[ (data['gender'] == 'male') & (data['country'] == 'Canada')]['gender'].count()

# Contar los datos de todos los campos
# data[ (data['gender'] == 'male') & (data['country'] == 'Canada')].count()
# Out:
# 7

# %% [markdown]
# ### Mostrar la cantidad de hombres y mujeres

# %%
# Argupamos mediante el genero y solo contamos
data.groupby('gender')['gender'].count()

# La alternativa es
# data.groupby('gender').count()
# Out:
# gender
# female    106
# male       94
# Name: gender, dtype: int64

# %% [markdown]
# ### Mostrar el pais con mas mujeres

# %%
data[ data['gender'] == 'female'].groupby('country')['country'].count().sort_values(ascending=False).head(1)
# data[ data['gender'] == 'female'].groupby('country').count().sort_values()
# Out:
# country
# Denmark    12
# Name: country, dtype: int64

# %% [markdown]
# ### Obtener los 5 paises con mas usuarios

# %%
data.groupby('country')['country'].count().sort_values(ascending=False).head(5)
# Out:
# country
# Ireland           16
# Denmark           16
# United Kingdom    15
# New Zealand       14
# Norway            14
# Name: country, dtype: int64
